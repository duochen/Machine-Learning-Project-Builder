# %% [markdown]
# # Lesson 5 Homework: Model Evaluation
#
# ## Is Accuracy Enough?
#
# **Course:** Python Machine Learning for High School Students
# **Lesson:** Lesson 5 -- Model Evaluation
# **Tool:** Google Colab or Jupyter Notebook
# **Estimated homework time:** 60 minutes
#
# In this homework notebook, you will practice evaluating a machine learning classification model.
#
# You will learn how to:
#
# - Load a dataset
# - Split data into training and test sets
# - Train a classification model
# - Evaluate the model using multiple metrics
# - Compare two models
# - Reflect on why accuracy alone is not enough
#
# > **Important:** This notebook uses a medical-related dataset for education only. It should not be used for real medical diagnosis.
#
# ---
#
# **Student Homework Version:** Each `Student TODO Section` code cell contains `# TODO:` comments for you to complete. Fill in each TODO yourself, then run the cell to check your work.

# %% [markdown]
# # Learning Goals
#
# By the end of this homework, students should be able to:
#
# 1. Use `train_test_split()` correctly.
# 2. Train a Logistic Regression model.
# 3. Evaluate a model using:
#    - Accuracy
#    - Confusion matrix
#    - Precision
#    - Recall
#    - F1-score
# 4. Visualize a confusion matrix.
# 5. Compare Logistic Regression with Random Forest.
# 6. Explain which evaluation metric matters most for a problem.
# 7. Connect model evaluation to STEM competition project quality.

# %% [markdown]
# # Homework Overview
#
# You will complete these tasks:
#
# 1. Load and prepare the dataset.
# 2. Train a Logistic Regression model.
# 3. Evaluate the model.
# 4. Interpret false positives and false negatives.
# 5. Compare the model with Random Forest.
# 6. Write a short reflection.
# 7. Complete optional advanced challenges.
#
# Each major section has a **Student TODO section** with `# TODO:` comments for you to fill in.

# %% [markdown]
# # Part 1: Import Libraries
#
# Before writing machine learning code, we need to import the Python libraries we will use.
#
# We will use:
#
# - `pandas` for tables
# - `numpy` for numerical operations
# - `matplotlib` for charts
# - `scikit-learn` for machine learning

# %%
# ============================
# Part 1: Import Libraries
# Student TODO Section
# ============================

# TODO: Import pandas as pd

# TODO: Import numpy as np

# TODO: Import matplotlib.pyplot as plt

# TODO: Import load_breast_cancer from sklearn.datasets

# TODO: Import train_test_split from sklearn.model_selection

# TODO: Import LogisticRegression from sklearn.linear_model

# TODO: Import RandomForestClassifier from sklearn.ensemble

# TODO: Import accuracy_score, confusion_matrix, classification_report, and ConfusionMatrixDisplay

# %% [markdown]
# # Part 2: Load and Prepare the Dataset
#
# We will use the **Breast Cancer Wisconsin dataset** built into scikit-learn.
#
# Each row represents one sample.
# Each column represents a numerical measurement.
#
# The target has two classes:
#
# - `0 = malignant`
# - `1 = benign`
#
# The model will learn from the measurements and predict the class.

# %%
# ============================
# Part 2: Load the Dataset
# Student TODO Section
# ============================

# TODO: Load the breast cancer dataset
# data = ...

# TODO: Create the feature table X using data.data and data.feature_names
# X = ...

# TODO: Create the target variable y using data.target
# y = ...

# TODO: Print the shape of X

# TODO: Print the shape of y

# TODO: Print the target names

# %% [markdown]
# # Part 3: Explore the Dataset
#
# Before training a model, we should inspect the data.
#
# We will check:
#
# 1. The first few rows
# 2. The class distribution
# 3. A simple class distribution chart

# %%
# ============================
# Part 3: Explore the Dataset
# Student TODO Section
# ============================

# TODO: Display the first 5 rows of X

# TODO: Count the number of samples in each target class

# TODO: Plot the class distribution as a bar chart

# %% [markdown]
# # Part 4: Split the Data
#
# We will split the data into:
#
# - **Training data:** used to train the model
# - **Test data:** used to evaluate the model
#
# We will use:
#
# - `test_size=0.2`, meaning 20% of the data is used for testing
# - `random_state=42`, so results are repeatable
# - `stratify=y`, so the class balance is similar in training and test sets

# %%
# ============================
# Part 4: Split the Data
# Student TODO Section
# ============================

# TODO: Use train_test_split to split X and y
# Requirements:
# - test_size=0.2
# - random_state=42
# - stratify=y

# X_train, X_test, y_train, y_test = ...

# TODO: Print X_train shape

# TODO: Print X_test shape

# TODO: Print y_train shape

# TODO: Print y_test shape

# %% [markdown]
# # Part 5: Train a Logistic Regression Model
#
# Now we will train our first classification model.
#
# We will use **Logistic Regression**.
#
# Logistic Regression is commonly used for binary classification problems.
#
# The model will learn from:
#
# - `X_train`
# - `y_train`
#
# Then we will test it using:
#
# - `X_test`
# - `y_test`

# %%
# ============================
# Part 5: Train Logistic Regression
# Student TODO Section
# ============================

# TODO: Create a LogisticRegression model
# Use max_iter=10000

# logistic_model = ...

# TODO: Train the model with X_train and y_train

# TODO: Print "Model training complete."

# %% [markdown]
# # Part 6: Evaluate Logistic Regression
#
# Now we will evaluate the model using the test set.
#
# We will calculate:
#
# 1. Accuracy
# 2. Confusion matrix
# 3. Classification report
#
# The classification report includes:
#
# - Precision
# - Recall
# - F1-score
# - Support

# %%
# ============================
# Part 6: Evaluate Logistic Regression
# Student TODO Section
# ============================

# TODO: Use the trained model to predict labels for X_test
# y_pred = ...

# TODO: Calculate accuracy
# accuracy = ...

# TODO: Print the accuracy

# TODO: Create the confusion matrix
# cm = ...

# TODO: Print the confusion matrix

# TODO: Display the confusion matrix using ConfusionMatrixDisplay

# TODO: Print the classification report

# %% [markdown]
# # Part 7: Interpret the Confusion Matrix
#
# The confusion matrix helps us understand the mistakes the model made.
#
# For this dataset:
#
# - `0 = malignant`
# - `1 = benign`
#
# The confusion matrix is arranged like this:
#
# | | Predicted Malignant | Predicted Benign |
# |---|---:|---:|
# | Actually Malignant | Correct malignant predictions | Malignant cases missed |
# | Actually Benign | Benign cases wrongly flagged | Correct benign predictions |
#
# In a medical-related problem, missing a malignant case may be more serious than incorrectly flagging a benign case.

# %%
# ============================
# Part 7: Interpret Mistakes
# Student TODO Section
# ============================

# TODO: Use the confusion matrix to calculate:
# 1. Correct malignant predictions
# 2. Malignant cases missed
# 3. Benign cases wrongly flagged
# 4. Correct benign predictions

# Hint:
# The confusion matrix format is:
# [[top_left, top_right],
#  [bottom_left, bottom_right]]

# TODO: Print each value with a clear label

# %% [markdown]
# # Part 8: Compare with Random Forest
#
# A good machine learning project often compares more than one model.
#
# Now we will train a **Random Forest Classifier** and compare it with Logistic Regression.
#
# Random Forest is a model made from many decision trees.

# %%
# ============================
# Part 8: Train and Evaluate Random Forest
# Student TODO Section
# ============================

# TODO: Create a RandomForestClassifier model
# Use random_state=42

# rf_model = ...

# TODO: Train the Random Forest model

# TODO: Make predictions on X_test

# TODO: Calculate Random Forest accuracy

# TODO: Print Random Forest accuracy

# TODO: Print Random Forest confusion matrix

# TODO: Display Random Forest confusion matrix

# TODO: Print Random Forest classification report

# %% [markdown]
# # Part 9: Create a Model Comparison Table
#
# Now we will compare the two models.
#
# We will create a table with:
#
# - Model name
# - Accuracy
# - Notes
#
# This is useful for STEM competition reports because it clearly shows that you tested multiple models.

# %%
# ============================
# Part 9: Model Comparison Table
# Student TODO Section
# ============================

# TODO: Create a pandas DataFrame with:
# - Model
# - Accuracy
# - Notes

# TODO: Display the comparison table

# TODO: Create a bar chart comparing model accuracy

# %% [markdown]
# # Part 10: Written Reflection
#
# Write a short reflection of **150–250 words**.
#
# Use this prompt:
#
# > In machine learning, why is accuracy alone not enough? Use your homework results as evidence. Explain how a confusion matrix, precision, recall, and F1-score help us understand the model better. Finally, explain how model evaluation would make a STEM competition project stronger.
#
# Your reflection should include:
#
# 1. One sentence explaining accuracy.
# 2. One sentence explaining the confusion matrix.
# 3. One sentence explaining precision or recall.
# 4. One example from your model result.
# 5. One connection to a STEM competition project.

# %% [markdown]
# ## Student Reflection Space
#
# Write your answer below.
#
# **My Reflection:**
#
# TODO: Write 150–250 words here.

# %% [markdown]
# # Part 11: Optional Challenge 1 — Cross-Validation
#
# A single train/test split can sometimes be lucky or unlucky.
#
# Cross-validation tests the model multiple times using different train/test splits.
#
# This gives a more stable estimate of model performance.

# %%
# ============================
# Part 11: Cross-Validation Challenge
# Student TODO Section
# ============================

# TODO: Import cross_val_score from sklearn.model_selection

# TODO: Create a LogisticRegression model with max_iter=10000

# TODO: Use cross_val_score with cv=5

# TODO: Print all five scores

# TODO: Print the average score

# TODO: Print the standard deviation

# %% [markdown]
# # Part 12: Optional Challenge 2 — Choose the Most Important Metric
#
# Imagine this model is part of a science fair project about early disease screening.
#
# Answer these questions:
#
# 1. Which metric would you care about most: accuracy, precision, recall, or F1-score?
# 2. Why?
# 3. What mistake would be more dangerous: missing a malignant case or incorrectly flagging a benign case?
# 4. How would you explain this to a judge?

# %% [markdown]
# # Homework Submission Checklist
#
# Before submitting, make sure your notebook includes:
#
# - Completed code
# - Logistic Regression accuracy
# - Logistic Regression confusion matrix chart
# - Logistic Regression classification report
# - Random Forest accuracy
# - Random Forest confusion matrix chart
# - Random Forest classification report
# - Model comparison table
# - 150–250 word written reflection
# - Optional challenge, if completed
#
# Suggested file name:
#
# `Lesson5_ModelEvaluation_Homework_FirstName_LastName.ipynb`

# %% [markdown]
# # Final Takeaway
#
# A strong machine learning project does not stop after training a model.
#
# A strong project explains:
#
# 1. How well the model performs
# 2. What kinds of mistakes it makes
# 3. Which metric matters most for the problem
# 4. Whether another model performs better
# 5. What the limitations are
#
# This is especially important for STEM competitions because judges want to see scientific thinking, not just working code.
